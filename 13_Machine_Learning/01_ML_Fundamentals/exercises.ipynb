# %% [markdown]
# # ML_Fundamentals Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Rules versus learning.** Write a function `rule_spam(text)` that returns `"SPAM"` when at least TWO of the words `"free"`, `"winner"`, `"prize"` appear in the lowercased text, otherwise `"HAM"`. Test it on `"winner winner claim your free prize"` (true spam) and `"our design tool won first prize at the conference"` (not spam). Add a one-line comment on why keyword rules stay brittle.

# %% [markdown]
# **2. Meet iris.** scikit-learn ships classic datasets that download nothing. Load `load_iris()` and wrap `.data` in a DataFrame with `columns=iris.feature_names`, then attach a `species_code` column holding `iris.target`. Print the DataFrame's shape and `iris.target_names`.

# %% [markdown]
# **3. X marks the features.** From your iris DataFrame build the conventional pair: `X` = the four measurement columns (a DataFrame), `y` = the `species_code` column (a Series). Print `X.shape`, `y.shape`, and the first example `X.iloc[0].to_dict()` next to its label `y.iloc[0]`.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Regression or classification.** Load `load_diabetes()` into a DataFrame (features plus a `target` column). Print its shape, the feature list, and `df["target"].describe().round(1)`. Finish with a comment: the target holds continuous numbers — which paradigm is this, and what change would turn it into classification?

# %% [markdown]
# **5. Sort the paradigms.** Decide for each scenario whether it is `supervised-regression`, `supervised-classification`, `unsupervised` or `reinforcement`: (a) predicting tomorrow's temperature, (b) grouping customers by behaviour with no labels, (c) spam vs ham from labelled emails, (d) a game agent learning from rewards, (e) estimating a flat's price. Store the answers in a dict and print it.

# %% [markdown]
# **6. Inside the Bunch.** A loaded sklearn dataset is a `Bunch` — a dict-like bundle. Print `type(iris)` and inspect the four attributes every loader provides (`data`, `target`, `feature_names`, `target_names`): their shapes/values, not just their existence.

# %% [markdown]
# **7. The module in miniature.** Run the canonical loop on iris: `train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)`, fit `KNeighborsClassifier(n_neighbors=5)` on the training rows, then print BOTH `model.score(X_train, y_train)` and `model.score(X_test, y_test)` to three decimals. Add a comment naming which score is the honest one and why.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Baseline before bragging.** Every real model must beat the do-nothing bar. On your iris test set compute the majority-class baseline: `pd.Series(y_te).value_counts(normalize=True).max()`. Print it next to the KNN test accuracy from Question 4, then print whether KNN clears the bar.

# %% [markdown]
# **9. Who generalises better.** Fit two very different learners on the SAME iris split: an unlimited `DecisionTreeClassifier(random_state=42)` and a `LogisticRegression(max_iter=5000)`. For each, print train and test accuracy on one line. Add a comment naming the model with the bigger train-vs-test gap and what that gap measures.
