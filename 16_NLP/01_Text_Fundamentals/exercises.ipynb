# %% [markdown]
# # Text Fundamentals Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Text is data.** To Python this review is just characters: `raw = "  LOVED it!!! Best purchase ever 😍  "`. Fold it to lowercase, trim the edges and split it into words in ONE chained expression, then print the word list and how many characters the raw string has.

# %% [markdown]
# **2. Glue and swap.** Given `ticket = "  ORDER #4521 has not arrived. Please HELP!  "`: glue `["urgent", "order", "4521"]` into one dash-separated id, test whether the ticket starts with `"ORDER"` (careful — trim FIRST), swap `#` for `"No."`, and slice out the first four words of the trimmed ticket.

# %% [markdown]
# **3. Code points both ways.** Print `ord("A")` and `ord("a")`, turn the code point `2535` back into its character with `chr`, then show that the emoji `"🙂"` is 1 character long but 4 bytes long once UTF-8 encoded.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. The flag surprise.** Store the Bangladesh flag emoji `"🇧🇩"` in a variable. Print its length, print the hex code point of every character inside it, then slice off just its first character and comment on what you got.

# %% [markdown]
# **5. Two spellings of one word.** Compare `e1 = "café"` with `e2 = "cafe\u0301"` using `==` and compare their lengths. Then fix `e2` with `unicodedata.normalize("NFC", ...)` and show both checks now agree.

# %% [markdown]
# **6. Profile your corpus.** For `REVIEWS` below compute three numbers: total words, vocabulary size (unique words) and the type-token ratio (`len(set(words)) / len(words)`, rounded to 3 places). Strip punctuation marks `.,!?` from token edges while collecting.
# ```
# REVIEWS = [
#     "The battery life is great and the screen is bright.",
#     "Battery drains fast but the screen looks stunning.",
#     "Great camera, poor battery, great price though.",
#     "The speaker is loud but the battery is poor.",
#     "Bright screen, great speakers, fair price. Loved it!",
#     "Poor packaging but fast delivery and a great price.",
# ]
# ```

# %% [markdown]
# **7. Rank the words.** Using the same flattening trick (`lower()`, split, strip `".,!?"`), build a `Counter` over all six reviews and print the top 6 words as little bar charts: `f"{word:>10} | {n} {'#' * n}"`. Which words dominate — and are they meaningful? Answer in a comment.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Why the naive splitter fails.** Split `story = "Dr. Smith paid $3.50 for tea. Then he walked home!"` with the tempting pattern `r"[.!?]"`, dropping empty parts. Print every piece and list, in comments, the THREE distinct ways this ruins the text.

# %% [markdown]
# **9. Repair the splitter with lookbehind.** Compile a verbose pattern that splits ONLY on whitespace sitting right after `.`, `!` or `?` (lookbehind `(?<=[.!?])`) while refusing positions just after `Dr.`, `Mr.`, `Mrs.`, `Ms.` or `St.` (negative lookbehinds). Split the story above, then also split:
# `"Mrs. Rahman ordered 2.5 kg of rice. It cost $12.75!! Was she happy? Yes. St. Martin tours were next."`
# and check that decimals and titles survive.
