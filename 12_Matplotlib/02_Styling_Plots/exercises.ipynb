# %% [markdown]
# # Styling Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Three ways to say a color.** Over `days = ["Sat", "Sun", "Mon", "Tue", "Wed"]`, a fitness app logged `walking = [42, 51, 38, 55, 60]`, `running = [20, 25, 15, 30, 28]` and `cycling = [33, 21, 40, 26, 35]` minutes. Color the three lines three different ways: a CSS name (`"seagreen"`), a hex code (`"#d1495b"`) and an RGB tuple (`(0.1, 0.3, 0.55)`). Give each a `label=` and show a legend.

# %% [markdown]
# **2. Four linestyles, one story.** With `months = [1, 2, 3, 4, 5, 6]` and `revenue = [42, 45, 51, 49, 58, 63]` (thousand BDT): draw revenue as a SOLID line (width 2.5), the plan (`0.85 *` each value) DASHED, last year (`0.7 *` each value) DASH-DOT, and a constant `break_even = [40] * 6` DOTTED - the last three width 1.8. Label all four and pin the legend to the upper left.

# %% [markdown]
# **3. Decode the shorthand.** In comments, translate each format string to plain keywords: `"ro--"`, `"g^-"`, `"k*"`, `"yo:"`. Then plot these three series on one labelled, gridded chart USING ONLY format strings: `city_a = [31, 33, 32, 34, 33, 35]` as red circles joined by dashes, `city_b = [24, 25, 23, 26, 27, 25]` as green triangles with a solid line, and `events = [2, 3, 1, 4, 2, 5]` as black stars with NO connecting line.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Marker gallery.** Five students scored `marks = [91, 74, 84, 67, 79]`: `students = ["Sarah", "Rakib", "Aisha", "Tanvir", "Nadia"]`. Looping over `styles = [("o", "#1f77b4"), ("s", "#ff7f0e"), ("^", "#2ca02c"), ("*", "#d62728"), ("D", "#9467bd")]`, draw ONE dot-only marker per student: markersize 12, that fill color, black marker edge, no line, named with `label=name`. Cap the y-axis at 0-100 and grid only the y-axis.

# %% [markdown]
# **5. Legend, placed and frameless.** Four delivery riders earned across `days = ["Sat", "Sun", "Mon", "Tue", "Wed", "Thu"]`: Karim `[35, 42, 38, 51, 47, 55]`, Juthi `[30, 36, 44, 40, 52, 49]`, Hasan `[25, 31, 29, 38, 41, 44]` and Priya `[40, 38, 48, 55, 50, 62]`. Plot each with a DIFFERENT marker (`o`, `s`, `^`, `*` - Priya's star markersize 11) and a label, then place a frameless, fontsize-10 legend in the upper left over a dashed half-transparent grid.

# %% [markdown]
# **6. See through the tangle.** Four training runs finished with these loss curves over `epochs = [1, 2, 3, 4, 5, 6, 7, 8]`: `[3.2, 2.9, 2.7, 2.5, 2.3, 2.2, 2.1, 2.0]`, `[3.5, 3.4, 3.0, 2.8, 2.6, 2.5, 2.4, 2.3]`, `[4.1, 3.6, 3.3, 3.0, 2.9, 2.7, 2.6, 2.6]` and `[2.9, 2.8, 2.6, 2.4, 2.2, 2.1, 2.0, 1.9]`. Loop over them and plot ALL FOUR in the SAME color (`"#1f77b4"`) with `alpha=0.35`, so the overlapping bundle stays readable. Title it `alpha = 0.35 - overlap stays readable`.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **7. Theme makeover.** Plot `sin(x)` and `cos(x)` for `x = np.linspace(0, 10, 100)` (linewidth 2.5, labelled, with a legend) under the `"ggplot"` style template. Confirm the theme exists by printing whether `"ggplot" in plt.style.available`. Afterwards RESET the theme and explain in a comment why skipping the reset would be dangerous.

# %% [markdown]
# **8. Dressed for the report.** Make the cafe's half-year revenue report-ready: `months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]`, `revenue = [42, 45, 51, 49, 58, 63]` thousand BDT. Line in hex `"#2a6f97"`, width 2.5, round markers. Bold 16-point title `Monthly Revenue - First Half`, 12-point axis labels, tick text shrunk to 10 via `tick_params`, dashed half-transparent grid.
