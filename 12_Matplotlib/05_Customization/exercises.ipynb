# %% [markdown]
# # Customization Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Crop to the story.** A bookstore's year: `month_num = list(range(1, 13))`, `sales = [310, 295, 340, 520, 610, 640, 430, 415, 450, 480, 700, 780]`. Plot the line (`"#2a6f97"`, round markers), then ZOOM into the spring surge with `plt.xlim(2.5, 6.5)` and `plt.ylim(250, 700)`, re-labelling the visible ticks via `plt.xticks(range(3, 7), ["Mar", "Apr", "May", "Jun"])`. Title it `Zoomed - the spring surge` and comment why zooms must be announced.

# %% [markdown]
# **2. Rotate the smear away.** A shop sold these `units = [820, 640, 590, 750, 310, 275]` for `products = ["Instant Noodles", "Milk Chocolate", "Green Tea", "Basmati Rice 5kg", "Olive Oil 1L", "Protein Bars"]`. Bar them in `"#2a9d8f"` on a `figsize=(9, 4)` canvas and make the long names fit with `plt.xticks(rotation=45, ha="right")`, shrinking y tick text to 9. Why do rotation and `ha="right"` travel as a pair?

# %% [markdown]
# **3. Draw the finish line.** An app grew `users = [1200, 1500, 1800, 2600, 2400, 3100, 2900, 3400, 3300, 4100, 4800, 5200]` over the twelve months of `months = ["Jan", ..., "Dec"]` (write the list out). Plot the line (`"#2a6f97"`, width 2.5, markers, label `Monthly users`) and add a dashed `"#e76f51"` threshold at `target = 4000` via `plt.axhline` with its own legend entry `Target (4,000)` built from an f-string. Legend upper left, ylabel `Active users`, faint dashed grid.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Mark the moment.** Finals changed everything: `weeks = ["W1", "W2", "W3", "W4", "W5", "W6", "W7", "W8"]` saw `study_hours = [3, 4, 3, 7, 8, 6, 9, 10]`. Plot the line (width 2.5, `"#2a6f97"`, markers, labelled) and mark WHERE finals began with a dash-dot `"#e76f51"` vertical line via `plt.axvline`, computing the x position with `weeks.index("W4")` rather than hard-coding it. Give the line a legend entry and title the chart `Vertical Line = Event Marker`.

# %% [markdown]
# **5. Point at the peak.** Website `visits = [4200, 4800, 5100, 6300, 5900, 7200, 6800, 7500]` over `months = ["Jan", ..., "Aug"]`. Plot the line (`"#d62728"`, width 2.5, round markers), then annotate the busiest month with an arrow: find the index with `int(np.argmax(visits))`, and `plt.annotate(f"Peak: {visits[peak_i]:,}")` pointing `xy=(peak_i, visits[peak_i])` from text parked at `xytext=(peak_i - 2.5, visits[peak_i] - 900)` with `arrowprops=dict(arrowstyle="->", color="gray")`, bold text. Why compute the peak instead of typing `(7, 7500)`?

# %% [markdown]
# **6. Ink belongs to data.** Take a plain revenue line - `months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]`, `revenue = [420, 380, 510, 480, 590, 650]` - and make it MINIMAL in the object-oriented style: `fig, ax = plt.subplots(figsize=(9, 4))`, line `"#2a6f97"` width 2.5 with markers, then hide the top and right spines with `ax.spines[["top", "right"]].set_visible(False)` and use a recessive dotted y-only grid. Which two borders stay, and why?

# %% [markdown]
# **7. Straighten the growth.** A video doubled daily: after `day = list(range(10))` days it had `views = [250, 500, 1000, 2000, 4000, 8000, 16000, 32000, 64000, 128000]`. Show BOTH views side by side (`figsize=(11, 4)`, two `plt.subplot(1, 2, n)` panels): LEFT a normal `plt.plot` (`"#e76f51"`) titled `Linear scale - early days vanish`; RIGHT `plt.semilogy` (`"#2a9d8f"`) titled `Log scale - doubling reads as a straight line`. Both with xlabel `Day`. Finish with `tight_layout()`, and comment what shape exponential growth takes on a log axis.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Calendar in colors.** Turn a week of focus scores into a HEATMAP: `days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]`, `blocks = ["06-09", "09-12", "12-15", "15-18", "18-21", "21-24"]`, and the 7x6 matrix `focus = [[55, 85, 70, 75, 60, 20], [60, 88, 68, 72, 62, 25], [58, 82, 66, 74, 64, 22], [52, 86, 69, 70, 58, 30], [50, 78, 60, 55, 48, 35], [35, 42, 50, 62, 70, 45], [30, 38, 46, 55, 60, 40]]`. Use `plt.imshow(focus, cmap="viridis", aspect="auto")`, a colourbar labelled `Focus score`, and `xticks`/`yticks` to name the blocks and days. On a `figsize=(8, 5)` canvas, titled `Weekly Focus Heatmap`. When you read it, WHEN does deep work happen?

# %% [markdown]
# **9. Set it once.** Stop repeating styling arguments: at the top, set `plt.rcParams["figure.figsize"] = [9, 4]`, `font.size = 11`, `axes.titleweight = "bold"` and `lines.linewidth = 2.5`. Then plot `np.linspace(0, 10, 100)` against `np.sin(x)` and `np.sin(2 * x)` with labels, a title and a legend using NO styling keyword arguments at all - every default comes from rcParams. Afterwards call `plt.rcdefaults()` and comment why, plus how you would export such a chart for a report.
