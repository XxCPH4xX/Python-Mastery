# %% [markdown]
# # Subplots Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Left and right slots.** Using the STATE-MACHINE style: on a `figsize=(10, 4)` canvas, put Sarah's `study = [2, 3, 5, 4, 6]` in the LEFT panel and her `sleep = [7, 8, 6, 9, 8]` in the RIGHT panel over `week = ["Sat", "Sun", "Mon", "Tue", "Wed"]` (sleep in `"#2a9d8f"`). Each panel gets its own title plus a `Day` xlabel.

# %% [markdown]
# **2. Panels count from one.** Build a 2x2 grid with FOUR separate `plt.subplot(2, 2, n)` calls (n = 1, 2, 3, 4). In slot n, plot `x = [1, 2, 3]` against `[n, 2*n, 3*n]` with round markers and title it `Slot {n}` using an f-string. Before running, predict: which corner is slot 3?

# %% [markdown]
# **3. Objects, not globals.** Redo a single plot in the OBJECT-ORIENTED style: `fig, ax = plt.subplots(figsize=(8, 4))`, then plot `months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]` vs `temp_c = [19, 22, 27, 30, 30, 29]` with `ax.plot` (color `"#2a6f97"`, round markers), `ax.set_title("Dhaka Average Temperature (Jan-Jun)")`, both `set_xlabel`/`set_ylabel`, and `ax.grid(True, linestyle="--", alpha=0.5)`.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Same ruler, both panels.** Riders Karim `[35, 42, 38, 51, 47, 55]` and Priya `[40, 38, 48, 55, 50, 62]` worked `days = ["Sat", "Sun", "Mon", "Tue", "Wed", "Thu"]`. Stack their earnings in a 2x1 OBJECT-ORIENTED grid with `sharex=True, sharey=True, figsize=(8, 6)` (Karim `"#2a6f97"` circles, Priya `"#e76f51"` squares). Loop over `axes` to `set_ylabel("Earnings")` and add a dashed grid to both. Comment WHY the sharing matters.

# %% [markdown]
# **5. One loop fills any grid.** Five subjects scored `marks = [88, 74, 91, 79, 84]`: `subjects = ["Math", "Physics", "Chemistry", "Biology", "English"]`. Create `fig, axes = plt.subplots(1, 5, figsize=(14, 3), sharey=True)` and fill EVERY panel with ONE `zip(axes.ravel(), subjects, marks)` loop: a bar per subject, colored `"#2a6f97"` when the mark reaches 80 else `"#adb5bd"`, titled with the subject at fontsize 10, y capped at 0-100. Give only the first panel a ylabel.

# %% [markdown]
# **6. Untangle the titles.** This grid was drawn but its long titles collide with the row above. Four subjects' quiz scores: `quizzes = {"Math": [88, 92, 79, 85, 90, 84], "Physics": [74, 71, 80, 68, 77, 72], "Chemistry": [81, 78, 85, 74, 83, 80], "Biology": [90, 86, 94, 88, 91, 87]}`, positioned at `[(0, 0), (0, 1), (1, 0), (1, 1)]`. Recreate the 2x2 `figsize=(12, 8)` grid of histograms (bins=4, white edges, `"#457b9d"`), each titled `"{subject} quiz scores - detailed breakdown"` with `Score`/`Students` labels - and ADD the missing line that rescues the layout.

# %% [markdown]
# **7. Give the main act more stage.** Rebuild the revenue/profit pair with UNEQUAL rows: `months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]`, `revenue = [420, 380, 510, 480, 590, 650]`, `profit = [42, 30, 65, 52, 80, 95]` (thousand BDT). Make a 2x1 grid, `sharex=True`, with `gridspec_kw={"height_ratios": [2, 1]}` so revenue (a 2.5-wide `"#2a6f97"` line with markers) takes the tall top panel and profit (`"#e9c46a"` bars) rides below. Label both y-axes `Thousand BDT` and tidy with `tight_layout()`.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. The dashboard.** Assemble a 2x2 student-analytics dashboard from ONE dataset: `weeks = list(range(1, 9))` with `study_avg = [3.0, 3.5, 4.0, 3.5, 5.0, 5.5, 6.0, 6.5]` (line, top-left); `subjects = ["Math", "Physics", "Chemistry", "Biology", "English"]` with `subj_marks = [88, 74, 91, 79, 84]` (bars, y 0-100, top-right); `all_marks = [72, 68, 88, 54, 91, 77, 63, 85, 79, 94, 58, 81]` (histogram, bins=6, bottom-left); and `stu_hours = [2, 3, 4, 5, 6, 7, 8, 4, 5, 6, 3, 9]` vs `stu_marks = [55, 62, 68, 74, 79, 85, 90, 66, 73, 78, 60, 92]` (scatter, s=60, black edges, bottom-right). Crown it with a bold 16-point `fig.suptitle("Student Analytics Dashboard")` and reserve headroom via `fig.tight_layout(rect=[0, 0, 1, 0.96])`.

# %% [markdown]
# **9. Layout by name.** Skip slot arithmetic: build `fig, axd = plt.subplot_mosaic([["main", "side"], ["main", "bottom"]], figsize=(11, 6))`, where the label `"main"` spans BOTH left rows. Into `axd["main"]` plot `revenue = [420, 380, 510, 480, 590, 650]` over the six months (2.5-wide `"#2a6f97"` line with markers); into `axd["side"]` bar `profit = [42, 30, 65, 52, 80, 95]` in `"#e9c46a"` with x tick labels rotated 90 at size 8; into `axd["bottom"]` histogram `daily = [480, 520, 610, 450, 700, 650, 720, 560, 690, 730, 610, 760]` (bins=6, white edges, `"#457b9d"`). Title each panel, `tight_layout`, show - and comment why names beat numbers.
