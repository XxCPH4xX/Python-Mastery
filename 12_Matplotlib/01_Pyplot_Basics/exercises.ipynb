# %% [markdown]
# # Pyplot Basics Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Plumbing check.** Import Matplotlib the canonical way (pyplot aliased as `plt`) and print the installed version number.

# %% [markdown]
# **2. Sarah's study log.** Sarah logged `weeks = [1, 2, 3, 4, 5, 6]` and `hours = [4, 7, 6, 9, 11, 14]`. Draw a line through the points with a round marker on each one, title the chart `Sarah's Weekly Study Hours`, and label both axes. (Keep both lists the same length — mismatched x/y raise a `ValueError`.)

# %% [markdown]
# **3. Positions as x-values.** A player's cumulative score after each level is `scores = [0, 50, 120, 180, 260, 310]`. Plot it passing ONLY this one list (with square markers), titled `Score After Each Level`, with `Level` and `Total score` as axis labels.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. A softer background.** The bookshop sold `sales = [320, 290, 410, 380, 450, 520]` books over `months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]`. Plot the line with round markers over a DASHED, softened grid, fully titled and labelled.

# %% [markdown]
# **5. Three friends, one canvas.** During exam week, `days = ["Sat", "Sun", "Mon", "Tue", "Wed"]`, Sarah studied `[2, 3, 5, 4, 6]` hours, Rakib `[1, 2, 2, 4, 5]` and Aisha `[3, 1, 4, 3, 7]`. Draw all three lines in ONE figure (call plot three times before showing), add a dashed grid and proper labels, then comment which colors Matplotlib picked.

# %% [markdown]
# **6. A formula, not a list.** Real curves come from formulas. Using NumPy, build `x = np.linspace(0, 2 * np.pi, 200)` and plot `y = np.sin(x)` with title `y = sin(x)`, axis labels `x` / `sin(x)`, and a dashed grid.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **7. show() separates.** In ONE cell, produce TWO separate charts: `week = [1, 2, 3, 4]` with `study = [4, 7, 6, 9]` and `sleep = [6, 7, 8, 6]`. Render the study chart first (round markers), then the sleep chart in green with its own title. Add a comment explaining why the sleep line never lands on the study chart.

# %% [markdown]
# **8. The six-line recipe.** From memory, apply the standard recipe to `month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]` and `temp_c = [19, 22, 27, 30, 30, 29]`: round markers, headline `Dhaka Average Temperature (Jan-Jun)`, ylabel `Temperature (°C)`, dashed grid, render. Number each of the six lines' jobs in a comment.
