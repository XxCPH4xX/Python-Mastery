# %% [markdown]
# # Finally Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Your first `finally`.** Build a `try`/`finally` where the `try` computes `result = 6 * 7` and prints it, and the `finally` prints `"experiment over"`. How many lines appear?

# %% [markdown]
# **2. Cleanup after a caught error.** Put `int("not today")` inside a `try` whose `except ValueError` prints a short apology, and add a `finally` that prints `"bench wiped down"`. Predict the output before running it.

# %% [markdown]
# **3. Full anatomy, happy path.** Lay out all four clauses around this job: the `try` doubles `n = 21`; an `except ValueError` prints `"unexpected problem"`; an `else` prints the result; a `finally` prints `"audit logged"`. Which lines appear — and does the `except` fire?

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Three paths through one function.** Write `safe_divide(a, b)` that divides inside a `try` and uses the full anatomy: `except ZeroDivisionError`, `except TypeError`, an `else` that prints the result, and a `finally` that prints `"attempt finished"`. Call it with `(12, 3)`, `(12, 0)` and `(12, "3")`.

# %% [markdown]
# **5. Close the file by hand.** Create `sample_data/exercise_log.txt` for writing (make the folder first with `pathlib`), keeping the `open()` call *before* the `try`. Inside the `try` write two step lines, then trigger a disaster with `1 / 0`. Handle it in `except`, close the file in `finally` (printing whether it is closed), and afterwards read the file back to prove both lines reached disk.

# %% [markdown]
# **6. Nested cleanup order.** Write `inner_job()` that raises `ValueError("sensor unplugged")` inside its own `try`/`finally`, where the `finally` prints `"inner finally -> buffer flushed"`. Call it from inside an outer `try` that catches the error. Who cleans up first — inner or outer?

# %% [markdown]
# **7. The `return` trap.** Two versions of a grading function:
#
# ```python
# def grade_v1():
#     try:
#         return "computed grade: A"
#     finally:
#         return "grade lost!"
#
# def grade_v2():
#     try:
#         return "computed grade: A"
#     finally:
#         print("(cleanup ran)")
# ```
#
# Predict what each returns, then run both and print the results. State the rule in a comment.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Release the connection, whatever happens.** Define a fake database connection class: its `query(sql)` method prints `"querying: <sql>"` and returns `[("Omar", 91)]`, but raises `ValueError("malformed SQL")` when the SQL contains `"DROP"`; its `close()` prints `"connection released"`. Connect, run one good query, then one destructive one — catching the error outside — and make sure the connection is released on **every** path.

# %% [markdown]
# **9. The four-clause file reader.** Combine everything from this module: write `robust_read(path)` using `try` / `except FileNotFoundError` / `except UnicodeDecodeError` / `else` returning the stripped text / `finally` closing the file (guard against it never having been opened). Prepare a good text file, a file holding raw bytes like `b"\xff\xfe not utf-8"`, and point it at a filename that does not exist.
