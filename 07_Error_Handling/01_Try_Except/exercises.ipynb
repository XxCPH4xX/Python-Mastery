# %% [markdown]
# # Try_Except Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Name that crash.** Each of these lines raises a different exception: `int("twelve")`, `"hello" - 1`, `[90, 85, 70][99]` and `{"name": "Sam"}["age"]`. Wrap each one in its own `try`/`except` that catches the *specific* error and prints it.

# %% [markdown]
# **2. Divide with a safety net.** Given `readings = [400, 0, 80]`, print `1000 / r` for every reading — but a zero reading should produce a friendly skip message instead of a crash, and the program must still reach its final line.

# %% [markdown]
# **3. Accept or reject.** Loop over `attempts = ["128", "12.5", "octet"]` and convert each entry to an `int` inside a `try`. Print an acceptance line showing the number when the conversion works, and a rejection line when it does not. Hint: success-only work belongs in an `else:` block.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. One try, two failure modes.** For each entry in `submissions = ["15", "0", "five"]`, compute `300 / int(entry)` inside a single `try` with **two** `except` blocks: one for text that is not a number at all, one for the number that makes division undefined.

# %% [markdown]
# **5. Handler order detective.** This snippet never reaches its `ValueError` handler:
#
# ```python
# try:
#     price = int("not a number")
# except Exception:
#     print("something went wrong")
# except ValueError:
#     print("that was not a number")
# ```
#
# Run it, explain the output in a comment, then rewrite it so the specific handler gets to speak.

# %% [markdown]
# **6. Capture the evidence.** Convert `"24 km"` to an `int` inside a `try`. When it fails, bind the exception with `as e` and print three lines: the technical type (`type(e).__name__`), the raw message (`e`), and a human-friendly hint for the user.

# %% [markdown]
# **7. Refuse nonsense loudly.** Write `withdraw(balance, amount)` that returns the new balance, but `raise`s a `ValueError` with a descriptive message when `amount <= 0` or when `amount` exceeds `balance`. Start from `balance = 200` and attempt withdrawals of `50`, `0` and `500`, catching your own error each time.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Age-gate validator.** A sign-up form collected the attempts `["abc", "-5", "17"]`. Write `parse_positive_int(text)` that returns a positive whole number or `raise`s a `ValueError` stating exactly why (reject decimals such as `"3.5"` too). Loop over the attempts: rejected ones print the reason; the first valid one prints the recorded age and stops the loop with `break`.

# %% [markdown]
# **9. Family-tree detective.** Use `issubclass()` to check three claims: `IndexError` and `KeyError` are children of `LookupError`, and `KeyboardInterrupt` is **not** a child of `Exception`. Then prove why the parent matters: catch `[10, 20][9]` and `{"page": 1}["chapter"]` each with a single `except LookupError`.
