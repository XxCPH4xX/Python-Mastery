# %% [markdown]
# # NumPy Reshape & Broadcasting Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Reshape basics.** Take `flat = np.arange(12)` and reshape it into a 3x4 grid. Print the grid, its shape, and whether it shares memory with `flat` (`np.shares_memory`). Did NumPy copy anything?

# %% [markdown]
# **2. The wildcard -1.** With `readings = np.arange(24)`, reshape to `(4, -1)` and to `(-1, 8)`, printing the resulting shapes. Then reshape a 3-D `images = readings.reshape(2, 3, 4)` back down to 1-D using `-1` alone. How many wildcards are allowed per reshape?

# %% [markdown]
# **3. Transpose it.** Given `grades = np.array([[78, 85, 90], [62, 71, 88]])` (2 students x 3 subjects), print `grades.T`, its shape, and whether `.T` shares memory with the original. Bonus: transpose the vector `v = np.array([1, 2, 3])` - what happened?

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. ravel vs flatten.** Build `grid = np.arange(6).reshape(2, 3)`. Take `grid.ravel()`, set its first element to 99, and print `grid` - changed! Rebuild `grid` fresh, do the same with `grid.flatten()`, and print `grid` again. Which one is the safe choice when you plan to edit?

# %% [markdown]
# **5. Add an axis.** Given `v = np.array([1.0, 2.0, 3.0])` of shape `(3,)`, turn it into: a column of shape `(3, 1)` with `v[:, np.newaxis]`, a row of shape `(1, 3)` with `v[np.newaxis, :]`, and back with `np.squeeze(row)`. Print every shape along the way.

# %% [markdown]
# **6. Stack them together.** Given `week1 = np.array([31.5, 32.0, 33.8])` and `week2 = np.array([30.2, 29.9, 34.1])`: join them as rows with `vstack` and end-to-end with `hstack`. Then with `a = np.array([[1, 2], [3, 4]])` and `b = np.array([[5, 6], [7, 8]])`: glue with `concatenate` on axis 0 and axis 1, then `stack` them and print the new layer dimension's shape.

# %% [markdown]
# **7. Broadcast or break.** With `M = np.arange(12).reshape(3, 4)`: add the row-shaped bonus `np.array([10, 20, 30, 40])` (works), the column-shaped `np.array([[100], [200], [300]])` (works), then TRY adding `vec = np.array([1, 2, 3])` inside `try/except` and print the `ValueError`. Fix it by reshaping `vec` with `vec[:, np.newaxis]` and print the successful result.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Normalize the columns.** Given the dataset `X = np.array([[1200, 3, 85], [1450, 4, 110], [900, 2, 60], [1600, 3, 130]], dtype=float)` (area, bedrooms, price), compute each column's mean and std with `axis=0`, then normalize in ONE line: `(X - means) / stds`. Verify by printing each normalized column's mean and std rounded to 6 decimals.

# %% [markdown]
# **9. From vector to batch.** With weights `W = np.arange(6, dtype=float).reshape(2, 3)` and one input sample `x = np.array([1.0, 2.0, 3.0])`: compute `W @ x` (shapes `(2,3) @ (3,)`). Then build `X_batch = x[np.newaxis, :]` - a batch of one - and compute `X_batch @ W.T`, printing the output shape. Why does the batch version need the extra axis?
