# %% [markdown]
# # LLM Fundamentals — Exercises
#
# > 📘 **Python Mastery** · Module 17 — LLM Engineering · Lesson 1/7
#
# These exercises reinforce the core concepts from the fundamentals lesson:
# next-token prediction, tokens and pricing, training stages, sampling mechanics,
# model selection, and the open vs closed weights tradeoff.

# %% [markdown]
# ## Exercise 1: Token Estimation and Cost Calculation
#
# **Conceptual + Coding**
#
# You're building a feature that summarizes customer reviews. Each review averages 800 characters,
# and you expect the summary to be about 60 tokens.
#
# **Tasks:**
# 1. Write a function `estimate_monthly_cost(reviews_per_day, chars_per_review, output_tokens, model)` that calculates the monthly cost (30 days) for processing reviews.
# 2. Calculate the monthly cost for processing 5,000 reviews/day on each Claude tier.
# 3. How many reviews could you process for $1,000/month on Haiku vs Opus?

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Understanding Training Stages
#
# **Conceptual**
#
# For each scenario below, identify which training stage(s) are primarily responsible for the model's behavior:
#
# 1. The model can complete Python functions with correct syntax
# 2. The model refuses to help with harmful requests
# 3. The model responds in a conversational format instead of just continuing text
# 4. The model knows that Paris is the capital of France
# 5. The model uses a warm, professional tone in customer support scenarios
# 6. The model can write haikus about programming
#
# Write your answers as a dictionary mapping scenario number to stage name(s):
# `{1: "pretraining", 2: "RLHF", ...}`

# %%
# Your answer here
training_stages = {
    # Fill in your answers
}

# %% [markdown]
# ## Exercise 3: Implementing Softmax with Temperature
#
# **Coding**
#
# Implement a complete sampling function that:
# 1. Takes logits and temperature as input
# 2. Applies softmax with temperature (with numerical stability)
# 3. Samples one token using the resulting probabilities
# 4. Returns both the sampled token and the full probability distribution
#
# Test your function with:
# - vocabulary: `["sunny", "cloudy", "rainy", "stormy"]`
# - logits: `[4.0, 2.5, 1.0, 0.2]`
# - temperatures: `[0.1, 1.0, 2.5]`
#
# Sample 5 times at each temperature and observe the diversity.

# %%
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 4: Top-p (Nucleus) Sampling
#
# **Coding**
#
# Implement top-p sampling:
# 1. Write a function `apply_top_p(probs, p)` that filters a probability distribution to keep only the smallest set of tokens whose cumulative probability reaches `p`
# 2. The function should return a new normalized probability distribution (with filtered-out tokens set to 0)
# 3. Test with `probs = [0.5, 0.25, 0.15, 0.06, 0.04]` and `p` values of `[0.5, 0.75, 0.95, 1.0]`
# 4. For each `p` value, show which tokens survive and their renormalized probabilities

# %%
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 5: Model Selection Decision Matrix
#
# **Practical Scenario**
#
# You're architecting three different features. For each, recommend a model tier and justify your choice:
#
# **Feature A: Email Autoresponder**
# - Classifies incoming emails into 5 categories
# - Generates a short acknowledgment (30-50 tokens)
# - Volume: 2 million emails/day
# - Requirements: fast response, low cost, accuracy ~85% is acceptable
#
# **Feature B: Legal Document Analysis**
# - Analyzes contracts (50-200 pages each)
# - Extracts key terms, identifies risks, checks compliance
# - Volume: 50 documents/day
# - Requirements: very high accuracy, handles complex reasoning
#
# **Feature C: Code Review Assistant**
# - Reviews pull requests for bugs and improvements
# - Typical PR: 500-2000 lines of code
# - Volume: 800 PRs/day
# - Requirements: good accuracy, helpful suggestions, reasonable cost
#
# Write a function that takes feature characteristics and returns a recommendation with reasoning.

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Entropy and Uncertainty
#
# **Coding + Analysis**
#
# Shannon entropy measures the uncertainty in a probability distribution.
#
# **Tasks:**
# 1. Implement `calculate_entropy(probs)` that computes Shannon entropy: `H = -Σ(p * log(p))`
# 2. Calculate entropy for these distributions:
#    - Confident: `[0.95, 0.03, 0.01, 0.01]` (model knows the answer)
#    - Uncertain: `[0.4, 0.3, 0.2, 0.1]` (model is guessing between options)
#    - Uniform: `[0.25, 0.25, 0.25, 0.25]` (model has no idea)
# 3. Create a function `assess_confidence(probs, threshold=1.0)` that returns "confident" if entropy < threshold, else "uncertain"
# 4. Explain why high entropy might indicate a hallucination risk

# %%
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 7: Tokenization Analysis
#
# **Coding + Practical**
#
# Different text types tokenize differently. The `/4` heuristic works for prose but breaks for code and JSON.
#
# **Tasks:**
# 1. Write a function `estimate_tokens(text, text_type)` that uses different divisors based on text type:
#    - `"prose"`: 4 chars/token
#    - `"code"`: 3 chars/token (denser)
#    - `"json"`: 2.5 chars/token (very dense)
#    - `"numbers"`: 1.5 chars/token (digits split aggressively)
# 2. Test with these samples and compare estimates:
#    - English paragraph (200 chars)
#    - Python function (200 chars)
#    - JSON payload (200 chars)
#    - Long number: `"48151623429513871984756"` (23 chars)
# 3. Calculate the cost difference for processing 100k requests on Sonnet if you underestimate by using prose rules for JSON

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Attention Masking Mechanics
#
# **Coding**
#
# Causal attention is what allows autoregressive generation.
#
# **Tasks:**
# 1. Implement a function `create_causal_mask(seq_len)` that returns a boolean mask where `mask[i, j] = True` if position `i` should NOT attend to position `j`
# 2. Apply the mask to a toy attention score matrix (4×4) by setting masked positions to `-inf`
# 3. Apply softmax row-wise to get attention weights
# 4. Verify that each token only has non-zero attention to itself and earlier tokens
# 5. Explain why this masking pattern is essential for generation

# %%
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 9: Open vs Closed Weights Decision Framework
#
# **Practical + Analysis**
#
# Build a decision framework for the open vs closed weights choice.
#
# **Tasks:**
# 1. Create a scoring function that takes these inputs:
#    - `data_sensitivity`: 0-10 scale (10 = highly sensitive)
#    - `daily_volume`: requests per day
#    - `has_ml_ops_team`: boolean
#    - `needs_fine_tuning`: boolean
#    - `budget_per_month`: USD
# 2. The function should return a recommendation: `"closed_api"`, `"open_weights"`, or `"hybrid"`
# 3. Include reasoning for the recommendation
# 4. Test with these scenarios:
#    - Healthcare chatbot: sensitive=9, volume=10k/day, no ML ops, no fine-tuning, budget=$5k
#    - Ad targeting: sensitive=3, volume=10M/day, has ML ops, needs fine-tuning, budget=$50k
#    - Internal docs Q&A: sensitive=7, volume=5k/day, no ML ops, no fine-tuning, budget=$2k

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Cost Optimization Strategy
#
# **Practical Scenario + Coding**
#
# You're running a customer support ticket classifier with these characteristics:
# - Current: 100% Opus
# - Volume: 50,000 tickets/day
# - Average ticket: 600 chars
# - Output: 25 tokens (classification + confidence)
# - Current monthly cost: calculate this first
#
# **Tasks:**
# 1. Calculate current monthly cost
# 2. Design a cascade strategy:
#    - Try Haiku first
#    - If confidence < threshold, escalate to Sonnet
#    - If still low confidence, escalate to Opus
# 3. Assume escalation rates: 20% Haiku→Sonnet, 5% Sonnet→Opus
# 4. Calculate new monthly cost
# 5. What's the percentage savings?
# 6. Write the `classify_with_cascade(ticket, confidence_threshold)` function structure (mock implementation)

# %%
# Your code here

# %% [markdown]
# ## Exercise 11: Hallucination Detection Heuristic
#
# **Challenge Problem**
#
# Build a simple hallucination detection system based on entropy and token probability analysis.
#
# **Tasks:**
# 1. Simulate a sequence of 20 token generations with probability distributions
# 2. For each position, calculate:
#    - Entropy of the distribution
#    - Probability of the chosen token
# 3. Flag positions as "high risk" if:
#    - Entropy > 2.0 (uncertain), OR
#    - Chosen token probability < 0.3 (sampling from the tail)
# 4. Calculate a "hallucination risk score" for the entire sequence (% of risky tokens)
# 5. Create visualizations showing entropy and token probability across the sequence
# 6. Explain when this heuristic would fail to detect hallucinations

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your code here

# %% [markdown]
# ## Exercise 12: Combined Temperature and Top-p
#
# **Challenge Problem**
#
# Real inference engines apply both temperature and top-p sampling together.
#
# **Tasks:**
# 1. Implement `sample_with_temperature_and_top_p(logits, temperature, top_p, rng)`
# 2. The function should:
#    - Apply temperature to logits
#    - Convert to probabilities with softmax
#    - Apply top-p filtering
#    - Sample from the filtered distribution
# 3. Test with:
#    - vocabulary: 10 words
#    - logits: `[5, 4, 3, 2, 1, 0, -1, -2, -3, -4]`
#    - Try all combinations: `T in [0.5, 1.0, 2.0]` × `p in [0.5, 0.9, 1.0]`
# 4. For each combination, sample 100 times and report:
#    - Which tokens appeared
#    - Empirical frequency distribution
#    - Diversity (number of unique tokens sampled)
# 5. Explain when you'd use `T=0.7, p=0.9` vs `T=1.5, p=0.95`

# %%
import numpy as np
from collections import Counter

# Your code here
