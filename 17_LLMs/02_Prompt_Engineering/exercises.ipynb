# %% [markdown]
# # Prompt Engineering — Exercises
#
# > 📘 **Python Mastery** · Module 17 — LLM Engineering · Lesson 2/7
#
# These exercises reinforce the core concepts from the prompt engineering lesson:
# zero-shot vs few-shot prompting, chain-of-thought reasoning, system messages,
# output formatting, and prompt optimization techniques.

# %% [markdown]
# ## Exercise 1: Zero-Shot Sentiment Analysis
#
# **Warm-up**
#
# Write a zero-shot prompt that classifies customer reviews into three categories:
# - Positive
# - Negative
# - Neutral
#
# **Requirements:**
# 1. Create a function `create_zero_shot_prompt(review_text)` that returns a complete prompt
# 2. The prompt should be clear and specific
# 3. Test with 3 sample reviews of varying sentiment

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Few-Shot Conversion
#
# **Warm-up**
#
# Convert your zero-shot prompt from Exercise 1 into a few-shot prompt with 3 examples.
#
# **Requirements:**
# 1. Create a function `create_few_shot_prompt(review_text, examples)`
# 2. Include 3 diverse examples (one for each sentiment)
# 3. Compare the structure with your zero-shot prompt

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: System Message Design
#
# **Warm-up**
#
# Design system messages for three different scenarios. Each system message should set the tone,
# define behavior, and establish constraints.
#
# **Scenarios:**
# 1. A customer support chatbot for a luxury hotel
# 2. A code review assistant for a Python team
# 3. A creative writing coach for beginners
#
# **Requirements:**
# - Each system message should be 2-4 sentences
# - Define persona, tone, and key behaviors
# - Explain your design choices

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Chain-of-Thought for Math
#
# **Practice**
#
# Create a chain-of-thought prompt for solving math word problems.
#
# **Test Problem:**
# "A bakery sells cupcakes for $3 each and cookies for $2 each. If Sarah buys 5 cupcakes and spends a total of $23, how many cookies did she buy?"
#
# **Requirements:**
# 1. Write a prompt that encourages step-by-step reasoning
# 2. Include phrases like "Let's break this down" or "Step by step"
# 3. Create a template that works for similar word problems

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: JSON Output Formatting
#
# **Practice**
#
# Create a prompt that extracts structured information from product descriptions and returns valid JSON.
#
# **Input Example:**
# "The UltraBoost 2024 running shoes feature responsive cushioning, breathable mesh upper, and come in sizes 7-13. Available in three colors: black, white, and navy. Price: $180. Perfect for long-distance runners."
#
# **Required JSON Structure:**
# ```json
# {
#   "product_name": "...",
#   "category": "...",
#   "features": [...],
#   "sizes": [...],
#   "colors": [...],
#   "price": 0.0,
#   "target_audience": "..."
# }
# ```

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Role-Based Prompting
#
# **Practice**
#
# Use role-based prompting ("Act as...") to get specialized responses.
#
# **Scenarios:**
# 1. "Act as a senior software architect" - review a system design
# 2. "Act as a security expert" - analyze a code snippet for vulnerabilities
# 3. "Act as a technical writer" - simplify a complex explanation
#
# **Requirements:**
# - Write the complete prompt for each scenario
# - Include context and specific questions
# - Explain why role-based prompting helps here

# %%
# Your code here

# %% [markdown]
# ## Exercise 7: Multi-Turn Conversation Structure
#
# **Practice**
#
# Design a multi-turn conversation for a technical support bot helping users debug Python errors.
#
# **Requirements:**
# 1. Create a conversation flow with at least 4 turns
# 2. Include:
#    - Initial system message
#    - User's first message (error report)
#    - Assistant's diagnostic questions
#    - User's answers
#    - Assistant's solution
# 3. Structure it as a list of message dictionaries with 'role' and 'content'

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: Complex Chain-of-Thought Reasoning
#
# **Challenge**
#
# Create a chain-of-thought prompt for a complex reasoning task: analyzing whether a business decision is sound.
#
# **Scenario:**
# "A SaaS company with 1,000 customers at $50/month is considering raising prices to $75/month. Their churn rate is currently 5% per month. Market research suggests 20% of customers would cancel if prices increase. Should they raise prices?"
#
# **Requirements:**
# 1. Design a prompt that breaks down the analysis into steps
# 2. Guide the model to consider:
#    - Current revenue
#    - Revenue after price increase
#    - Impact of churn
#    - Net revenue change
#    - Other factors (customer lifetime value, market positioning)
# 3. Request a clear recommendation with reasoning

# %%
# Your code here

# %% [markdown]
# ## Exercise 9: Handling Edge Cases
#
# **Challenge**
#
# Create a robust prompt that handles edge cases gracefully for a task: extracting dates from natural language.
#
# **Test Cases:**
# 1. "The meeting is scheduled for next Tuesday"
# 2. "I'll send it by end of day"
# 3. "Let's meet sometime in Q2"
# 4. "The deadline was yesterday"
# 5. "No specific date mentioned"
#
# **Requirements:**
# 1. Handle relative dates, vague dates, and missing dates
# 2. Return a consistent JSON structure with confidence level
# 3. Include instructions for ambiguous cases

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: Prompt Optimization Comparison
#
# **Challenge**
#
# Take a poorly written prompt and optimize it through multiple iterations.
#
# **Starting Prompt (Poor):**
# "Write code"
#
# **Task:** Create a function that calculates the Fibonacci sequence up to n terms.
#
# **Requirements:**
# 1. Create 4 versions of increasing quality:
#    - Version 1: Minimal (like the starting prompt)
#    - Version 2: Add context and constraints
#    - Version 3: Add output format requirements
#    - Version 4: Add examples and edge cases
# 2. For each version, explain what you improved and why
# 3. Analyze the tradeoff between prompt length and output quality

# %%
# Your code here
