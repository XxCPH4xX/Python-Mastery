# %% [markdown]
# # Polymorphism Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. One loop, many voices.** Create `Animal` (with `name` and `speak()` returning `"..."`) plus `Dog` and `Cat` subclasses that each override `speak()`. Put one of each into a `farm` list and print their voices with a SINGLE line inside one loop. Then define a brand-new `Duck` subclass, append it to `farm`, and re-run the SAME loop. How many characters of loop code needed changing?

# %% [markdown]
# **2. Built-ins do it too.** Call `len()` on a string, a list, a dict and `range(100)`, printing each result. Then call `__len__()` directly on the string and the list. In one comment, state what one function name plus many implementations proves.

# %% [markdown]
# **3. Operators join in.** Predict the output of `7 + 5`, `"poly" + "morphism"`, `[1, 2] + [3]` and `3 * "ab"` — then print all four. How many different operations does the single `+` symbol perform here?

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Strangers that quack.** Define THREE unrelated classes — no common parent anywhere — that all have a `quack()` method (be inventive: `Duck`, `Robot`, `Prankster`). Loop over one instance of each calling `quack()`. Then add a fourth class with NO `quack()` and show, via `try`/`except AttributeError`, what happens when the loop reaches it.

# %% [markdown]
# **5. Teach `+` about money.** Define `Money` holding an `amount`, with `__add__` returning a brand-new `Money` and `__repr__` like `Money(330)`. Add lunch (250) and coffee (80) and print the result; then add a tip of `20` to THAT sum and print it again.

# %% [markdown]
# **6. The shape contract.** Write a base class `Shape` whose `area()` RAISES `NotImplementedError("subclass must implement area()")`. Implement `Circle` (from `radius`) and `Square` (from `side`) on top of it. Loop over a circle of radius 3 and a square of side 4 printing each area, then prove the unfilled contract fails loudly by calling `Shape().area()` inside `try`/`except`.

# %% [markdown]
# **7. Retire the if/else chain.** Here is the road not taken:
#
# ```python
# def make_sound(animal):
#     kind = type(animal).__name__
#     if kind == "Dog":
#         return "Woof!"
#     elif kind == "Cat":
#         return "Meow."
#     else:
#         raise ValueError(f"I don't know a {kind}")
# ```
#
# Demonstrate the problem: define empty `Dog`, `Cat` AND `Cow` classes, show `make_sound(Cow())` blowing up (catch the `ValueError`). Then replace the whole scheme with `Dog`/`Cat`/`Cow` classes that share a `speak()` method plus one loop — and state in a comment what a new species costs now.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Uniform checkout.** Implement `CardPayment(last4)`, `PayPalPayment(email)` and `WalletPayment(provider)`, each with `pay(amount)` returning a confirmation string. Write `checkout(total, methods)` that prints an invoice header and processes EVERY method with the same one-line call. Run one invoice through all three, then define a `CryptoPayment` class and run a second invoice — `checkout` must not change by a single character.

# %% [markdown]
# **9. Broadcast with a contract.** Define a base class `Notifier` whose `send(message)` raises `NotImplementedError`. Subclass it as `EmailNotifier`, `SmsNotifier` and `PushNotifier`, each implementing `send`. Write `broadcast(message, channels)` that loops over the channels. Send one message through all three; then define `LazyNotifier` that inherits WITHOUT implementing `send` and show, inside `try`/`except`, that it crashes loudly.
