# %% [markdown]
# # Inheritance Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Your first subclass.** Define `Person` with `name`, `age` and an `introduce()` method. Create `Student(Person)` that adds ONLY an `enroll(course)` method. Instantiate a student, call BOTH methods, and confirm with `isinstance` that the student is-a `Person`.

# %% [markdown]
# **2. Free machinery.** Define `Vehicle` with a `brand` attribute and a `describe()` method; make `Motorcycle(Vehicle)` whose body is only a docstring and `pass`. Instantiate the motorcycle and call `describe()` — explain in a comment where the method came from.

# %% [markdown]
# **3. Extend the constructor with `super()`.** `Employee` stores `name` and `salary`. Write `Manager(Employee)` that ALSO stores `team_size`, delegating the shared part with `super().__init__()` as the first line of the child constructor. Print all three attributes of a manager.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Override, then extend.** `Animal.speak()` returns `"..."`. `Dog` overrides it to return `"<name>: Woof!"`. Then `RobotDog(Dog)` EXTENDS it: reuse `super().speak()` and wrap the answer as `"[beep] <dog answer>"`. Show all three speakers — including a plain `Animal` — in one loop.

# %% [markdown]
# **5. The forgotten super.** This child compiles happily and then betrays you:
#
# ```python
# class BadStudent(Person):
#     def __init__(self, student_id):
#         self.student_id = student_id
# ```
#
# (Define any `Person` you like first.) Instantiate `BadStudent`, try to read `.name`, catch the exception, and explain in a comment why it happens. Then write the corrected `GoodStudent` that also takes `name` and `age`.

# %% [markdown]
# **6. Who answers? Climb the MRO.** Build the chain `Animal -> Dog -> Puppy`: `Animal` has `name`, `speak()` returning `"..."` and `info()`; `Dog` overrides `speak()`; `Puppy` adds only `fetch()`. On a puppy named Pip call all three methods and read `.name`, noting in comments which level supplied each. Finish by printing `[c.__name__ for c in Puppy.__mro__]`.

# %% [markdown]
# **7. A smarter list.** Subclass `list` as `ScoreList`, adding `average()` and `top()` (returning `None` when empty). Start from `[88, 92, 79]`, then `append(95)` and `sort()` to prove every native method survived. Print the sorted list, the statistics, and whether `isinstance(scores, list)` holds.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Two parents, one winner.** `Swimmer` and `Flyer` both define `move()`. Create `Duck(Swimmer, Flyer)` and PREDICT `d.move()` before running; print it alongside `[c.__name__ for c in Duck.__mro__]`. Then build the diamond (`A` defines `hello`; `B` and `C` each override it; `D(B, C)` adds nothing) and predict `D().hello()` before checking it against `D.__mro__`.

# %% [markdown]
# **9. Has-a beats is-a.** Define `PetrolEngine` and `ElectricEngine`, each with a distinctive `start()`. Write `Car(model, engine)` that STORES the engine as an attribute and delegates to it in its own `start()`. Drive a petrol car and an electric car through the same `Car` code, and explain in a comment why swapping engines would be painful with inheritance instead.
