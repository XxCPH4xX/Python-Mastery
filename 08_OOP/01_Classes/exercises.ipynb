# %% [markdown]
# # Classes Exercises

# %% [markdown]
# Write your answer in the empty code cell under each question. Check yourself against `solutions.ipynb` when done.
#
# **Part 1** = warm-up · **Part 2** = practice · **Part 3** = challenge.

# %% [markdown]
# ## Part 1 — Warm-up

# %% [markdown]
# **1. Your first class.** Define a `Dog` class with a docstring and an `__init__` taking `name` and `age`, stored as instance attributes. Create two dogs and print each one's name and age.

# %% [markdown]
# **2. The empty blueprint.** Define an empty class `Stub` (docstring + `pass`), instantiate it, then print the class itself, its type via `type(Stub)`, and the new instance.

# %% [markdown]
# **3. Hello, `self`.** Give a `Greeter` class a `name` attribute and a `greet()` method returning `"Hi, I'm <name>"`. Call it the normal way (`obj.greet()`) and the under-the-hood way (`Greeter.greet(obj)`), then print whether the results are identical.

# %% [markdown]
# ## Part 2 — Practice

# %% [markdown]
# **4. Bank account basics.** Build `BankAccount` with `owner` and `balance` (default `0`). Add `deposit(amount)` and `withdraw(amount)` methods that RETURN a status string, refusing any withdrawal larger than the balance. Then open an account for Sarah with 100, deposit 50, withdraw 30, and try to withdraw 1000.

# %% [markdown]
# **5. Shared scoreboard.** Give a `Player` class a class attribute `player_count = 0` that `__init__` bumps by one for every new player. Create four players, then print the total from the CLASS and from one instance — both must agree.

# %% [markdown]
# **6. Two costumes for one object.** Write a `Movie` class with `title` and `year`, a `__str__` like `'Inception' (2010)` and a `__repr__` that looks like the code that would rebuild it. Print the object, print `repr()` of it, and print a list containing it twice — notice which method each line uses.

# %% [markdown]
# **7. Missing-self detective.** This method crashes the moment you call it:
#
# ```python
# class Robot:
#     def status():
#         return "all systems go"
#
# r = Robot()
# r.status()
# ```
#
# Run the call inside a `try`, catch the `TypeError`, and explain in a comment exactly why Python complains about arguments. Then provide the fixed class.

# %% [markdown]
# ## Part 3 — Challenge

# %% [markdown]
# **8. Playlist planner.** Design a `Playlist` class: class attribute `platform = "PyMusic"`; instance attributes `owner` and `songs` (accepting an optional starter list); `add_song(title)` appending the song and returning the new song count; and `summary()` returning e.g. `Sarah - 3 songs on PyMusic`. Exercise every feature on two different playlists.

# %% [markdown]
# **9. From parallel lists to a class.** This procedural version works, but nothing ties the data together:
#
# ```python
# names = ["Sarah", "Rafi"]
# grades = [[88, 92, 79], [55, 61, 47]]
#
# def average_of(grade_list):
#     return sum(grade_list) / len(grade_list)
# ```
#
# Rewrite it as a `Student` class holding `name` and `grades`, with `average()` and `has_passed()` methods (pass mark 60), producing the same report for both students without any parallel lists.
