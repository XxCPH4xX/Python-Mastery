# %% [markdown]
# # Reproducibility & Environments - Exercises
#
# > 📘 **Python Mastery** · Module 18 — MLOps · Lesson 2/6
#
# These exercises test your understanding of reproducible ML workflows: dependency management, seeding, config-driven training, experiment organization, and data versioning.

# %% [markdown]
# ## Exercise 1: Dependency Detective (Conceptual)
#
# You receive a model trained 6 months ago. The repo contains:
# - `train.py` (the training script)
# - `model.pkl` (the trained model)
# - `requirements.txt` with entries like `numpy>=1.20`, `scikit-learn>=0.24`
#
# Your teammate tries to load the model and gets: `AttributeError: 'RandomForestClassifier' object has no attribute 'n_features_'`
#
# **Questions:**
# 1. What is the most likely root cause of this error?
# 2. What information is missing from the repo that would prevent this?
# 3. Write the exact `pip` command that would have captured the complete environment at training time.
# 4. Should the original developer have used `>=` or `==` in requirements.txt for an application? Why?

# %%
# Your answers here as comments
# 1. Root cause:
# 
# 2. Missing information:
# 
# 3. Command:
# 
# 4. >= vs ==:

# %% [markdown]
# ## Exercise 2: The Seed Utility
#
# Write a `set_all_seeds` function that seeds Python's `random`, NumPy's global RNG, and returns a modern `Generator`. Then prove it works by running the same randomized operation twice and asserting the results are identical.

# %%
import os
import random
import numpy as np

def set_all_seeds(seed: int = 42) -> np.random.Generator:
    """Seed all random sources used in classic ML stack."""
    # YOUR CODE HERE
    pass

# Test: create two random samples with the same seed
# YOUR CODE HERE

# Assert they are identical

# %% [markdown]
# ## Exercise 3: Reproducible Split Detective
#
# This code is supposed to be reproducible, but it produces different test sets on every run. Find and fix ALL the bugs.

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

SEED = 42
np.random.seed(SEED)

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)

print("Test accuracy:", model.score(X_test, y_test))
print("First 5 predictions:", model.predict(X_test[:5]))

# The output should be IDENTICAL every time you run this cell

# %% [markdown]
# ## Exercise 4: Config-Driven Training
#
# Create a `TrainConfig` dataclass with fields for `model_type`, `n_estimators`, `max_depth`, `seed`, and `test_size`. Train a RandomForestClassifier using config values, save both the config and model to a run directory, then reload and verify they match.

# %%
import json
from dataclasses import dataclass, asdict
from pathlib import Path
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import joblib

@dataclass
class TrainConfig:
    # YOUR CODE HERE
    pass

# Create a config instance
# YOUR CODE HERE

# Train using the config
# YOUR CODE HERE

# Save config and model to 'sample_runs/config_test/'
# YOUR CODE HERE

# Reload and verify
# YOUR CODE HERE

# %% [markdown]
# ## Exercise 5: Run Directory Factory
#
# Write a `create_run_directory` function that:
# 1. Takes a base path, experiment name, and optional timestamp
# 2. Creates `{base}/{timestamp}_{name}/` directory structure
# 3. Returns the Path object
#
# Then write a `save_experiment` function that saves config, metrics, and model to that directory.

# %%
import json
from datetime import datetime
from pathlib import Path
import joblib

def create_run_directory(base: str, name: str, timestamp: str | None = None) -> Path:
    """Create timestamped run directory."""
    # YOUR CODE HERE
    pass

def save_experiment(run_dir: Path, config: dict, metrics: dict, model=None) -> None:
    """Save all experiment artifacts to run directory."""
    # YOUR CODE HERE
    pass

# Test it
test_dir = create_run_directory("sample_runs", "test_exp", "20260826_1200")
save_experiment(test_dir, 
                config={"lr": 0.01, "epochs": 10},
                metrics={"accuracy": 0.95, "loss": 0.12})

print("Files created:", sorted([p.name for p in test_dir.iterdir()]))

# %% [markdown]
# ## Exercise 6: Content Addressing for Data
#
# Write a function `compute_data_hash` that takes a file path and returns a SHA-256 hash of its contents (first 12 characters). Then demonstrate that:
# 1. Same content = same hash
# 2. Different content = different hash
# 3. Even one byte change = completely different hash

# %%
import hashlib
from pathlib import Path

def compute_data_hash(filepath: Path) -> str:
    """Return first 12 chars of SHA-256 hash of file contents."""
    # YOUR CODE HERE
    pass

# Create test files and demonstrate the three properties
# YOUR CODE HERE

# %% [markdown]
# ## Exercise 7: Float Comparison Trap
#
# Demonstrate why `==` fails for floating-point comparisons and implement a safe comparison function using `np.allclose`.

# %%
import numpy as np

# Show the associativity problem
a, b, c = 0.1, 0.2, 0.3

# YOUR CODE HERE: demonstrate (a+b)+c != a+(b+c)

def safe_compare_predictions(pred1: np.ndarray, pred2: np.ndarray, rtol: float = 1e-9) -> bool:
    """Safely compare two prediction arrays."""
    # YOUR CODE HERE
    pass

# Test with nearly-identical arrays
predictions_1 = np.array([0.1 + 0.2, 0.3 + 0.4])
predictions_2 = np.array([0.3, 0.7])

print("Direct == :", (predictions_1 == predictions_2).all())
print("Safe compare:", safe_compare_predictions(predictions_1, predictions_2))

# %% [markdown]
# ## Exercise 8: The Full Pipeline
#
# Combine everything: Create a complete reproducible training pipeline that:
# 1. Uses a config dataclass
# 2. Seeds all random sources
# 3. Trains a model
# 4. Saves everything to a timestamped run directory
# 5. Includes a data version hash in the config
#
# Then run it twice with the same config and prove the predictions are identical.

# %%
import json
import hashlib
from dataclasses import dataclass, asdict
from pathlib import Path
import numpy as np
import joblib
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

@dataclass
class Config:
    # YOUR CODE HERE: add fields for n_estimators, max_depth, seed, test_size, data_hash
    pass

def set_all_seeds(seed: int) -> np.random.Generator:
    # YOUR CODE HERE
    pass

def train_pipeline(config: Config) -> tuple:
    """Run complete training pipeline, return (model, test_predictions, test_score)."""
    # YOUR CODE HERE
    pass

# Run 1
cfg1 = Config(n_estimators=50, max_depth=5, seed=42, test_size=0.2, data_hash="abc123")
# YOUR CODE HERE

# Run 2 (same config)
cfg2 = Config(n_estimators=50, max_depth=5, seed=42, test_size=0.2, data_hash="abc123")
# YOUR CODE HERE

# Verify predictions are identical
# YOUR CODE HERE

# %% [markdown]
# ## Exercise 9: Environment Snapshot (Practical)
#
# Write code to capture and display the current environment's key package versions. Save this snapshot to a JSON file that could be committed alongside experimental results.

# %%
from importlib.metadata import version
import json
from pathlib import Path

def capture_environment() -> dict:
    """Capture versions of key ML packages."""
    packages = ["numpy", "pandas", "scikit-learn", "matplotlib", "joblib"]
    # YOUR CODE HERE: return dict of package: version
    pass

# Capture and save
# YOUR CODE HERE

# Display
print("Current environment:")

# %% [markdown]
# ## Exercise 10: Debugging Irreproducibility (Challenge)
#
# This function is supposed to be reproducible but isn't. It has THREE bugs. Find and fix them all.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits

def buggy_training_pipeline(seed=42):
    # Bug 1: Only numpy is seeded
    np.random.seed(seed)
    
    X, y = load_digits(return_X_y=True)
    
    # Bug 2: train_test_split doesn't get random_state
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    
    # Shuffle training data (realistic preprocessing)
    shuffle_idx = np.random.permutation(len(X_train))
    X_train = X_train[shuffle_idx]
    y_train = y_train[shuffle_idx]
    
    # Bug 3: RandomForest doesn't get random_state
    model = RandomForestClassifier(n_estimators=20, max_depth=10)
    model.fit(X_train, y_train)
    
    return model.predict(X_test)

# Test reproducibility
pred1 = buggy_training_pipeline(seed=7)
pred2 = buggy_training_pipeline(seed=7)

print("Predictions match:", (pred1 == pred2).all())
print("This should be True but isn't! Fix the bugs.")

# YOUR FIXED VERSION HERE
def fixed_training_pipeline(seed=42):
    # YOUR CODE HERE
    pass

# %% [markdown]
# ## Exercise 11: PYTHONHASHSEED Mystery (Conceptual)
#
# Explain why setting `os.environ["PYTHONHASHSEED"]` inside a running Python process doesn't make set/dict iteration order reproducible, and what you should do instead.

# %%
# Write your explanation as comments:
# 
# Why it doesn't work:
# 
# 
# What to do instead:
# 
# 
# When this matters in ML:
#

# %% [markdown]
# ## Exercise 12: Experiment Comparison (Challenge)
#
# Write a function that:
# 1. Accepts a list of run directories
# 2. Loads their configs and metrics
# 3. Returns a pandas DataFrame comparing them
# 4. Sorts by a specified metric (default: accuracy, descending)
#
# Test it on multiple run directories from Exercise 8.

# %%
import json
from pathlib import Path
import pandas as pd

def compare_runs(run_dirs: list[Path], sort_by: str = "accuracy", ascending: bool = False) -> pd.DataFrame:
    """Load and compare multiple experimental runs."""
    # YOUR CODE HERE
    pass

# Create multiple runs with different configs
# YOUR CODE HERE

# Compare them
# YOUR CODE HERE
