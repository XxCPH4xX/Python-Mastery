# %% [markdown]
# # MLOps Overview - Exercises
#
# > 📘 **Python Mastery** · Module 18 — MLOps · Lesson 1/6
#
# These exercises reinforce the core concepts of MLOps, drift types, lifecycle stages, and maturity levels.

# %% [markdown]
# ## Exercise 1: Understanding MLOps (Conceptual)
#
# **Question:** Explain in 2-3 sentences why traditional DevOps practices are insufficient for machine learning systems. What are the three core artifacts that make ML systems different?

# %% [markdown]
# ## Exercise 2: Drift Detective (Coding)
#
# You have a credit card fraud detection model. Implement a function that simulates both data drift and concept drift, then create metrics to detect each type.
#
# **Requirements:**
# - Create a synthetic fraud dataset with 3 features: transaction_amount, time_of_day, merchant_category
# - Train a baseline model on "Month 1" data
# - Generate "Month 6" data exhibiting BOTH drift types
# - Calculate and report accuracy degradation
# - Identify which features drifted and how

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# Your code here

# %% [markdown]
# ## Exercise 3: The Frozen Model Problem (Conceptual)
#
# **Scenario:** A ride-sharing company deployed a surge pricing model in January 2025. The model predicts demand based on:
# - Time of day
# - Day of week
# - Weather conditions
# - Historical demand patterns
#
# By August 2025, the model's predictions are consistently off. List 3 specific real-world changes that could cause this, and classify each as data drift, concept drift, or both. Explain your reasoning.

# %% [markdown]
# ## Exercise 4: Comparing ML Decay to Software Decay (Coding)
#
# Create two functions:
# 1. `traditional_software()` - simulates a tax calculator that breaks only when code/rules change
# 2. `ml_system()` - simulates a model that degrades as input distribution shifts
#
# Run both over 12 "months" and plot their reliability over time.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your code here

# %% [markdown]
# ## Exercise 5: ML Lifecycle Mapping (Practical)
#
# **Scenario:** Your team wants to build a customer churn prediction model for a telecom company.
#
# For each lifecycle stage (Scope, Data, Model, Deploy, Monitor, Retrain), write:
# - One key question you must answer
# - One artifact you should produce
# - One way the stage could fail silently

# %% [markdown]
# ## Exercise 6: Component Matching (Conceptual)
#
# Match each MLOps tool category to the problem it solves:
#
# **Categories:**
# 1. Experiment tracking
# 2. Data versioning
# 3. Model registry
# 4. Orchestration
# 5. Serving
# 6. Monitoring
#
# **Problems:**
# A. "Which parameters produced our best model last month?"
# B. "Is the input distribution shifting away from training data?"
# C. "How do we run data validation before training every night at 2 AM?"
# D. "Which model version is currently in production?"
# E. "How do applications call the model via HTTP?"
# F. "Did someone edit the training CSV, or is this the same data?"

# %% [markdown]
# ## Exercise 7: Maturity Assessment (Coding + Practical)
#
# Implement a `maturity_assessment()` function that asks 10 yes/no questions and places a team at Level 0, 1, or 2. Then use it to assess a fictional team based on this description:
#
# *"The data science team trains models in Jupyter notebooks. They have a shared Git repo for code. Models are saved to a 'models/' folder with timestamps. Retraining happens when someone remembers to run the notebook. There's a dashboard showing model accuracy that updates monthly. Deployment means copying the .pkl file to the production server."*

# %%
# Your code here

# %% [markdown]
# ## Exercise 8: DevOps vs MLOps Comparison Table (Practical)
#
# Create a detailed comparison table with at least 8 dimensions comparing traditional software (DevOps) to ML systems (MLOps). Include dimensions like: versioning, testing, monitoring, deployment triggers, failure modes, rollback complexity, etc.

# %% [markdown]
# ## Exercise 9: Postmortem Analysis (Practical)
#
# **Scenario:** An e-commerce recommendation model was deployed in January. By June, click-through rates dropped 40%, but no errors were logged.
#
# Investigation revealed:
# - A new product category was added in March (electronics previously only sold clothing)
# - The mobile app was redesigned in April, changing how users browse
# - A competitor launched in May, changing user behavior
#
# Write a postmortem report including:
# 1. Root cause analysis
# 2. Classification of each issue (data drift / concept drift / other)
# 3. What monitoring would have caught this earlier
# 4. Concrete action items with owner assignments

# %% [markdown]
# ## Exercise 10: Simulate the Feedback Loop (Coding)
#
# Implement a simplified ML lifecycle loop that:
# 1. Trains a model on initial data
# 2. Serves predictions for several time periods
# 3. Monitors performance degradation
# 4. Triggers retraining when accuracy drops below threshold
# 5. Loops back to serve with the new model
#
# Use a simple synthetic dataset where the distribution shifts gradually over time.

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Your code here

# %% [markdown]
# ## Exercise 11: Role Assignment (Practical)
#
# You're building a fraud detection system for a fintech startup with these team members:
# - Alex (ML background, strong Python)
# - Jordan (data engineering, SQL expert)
# - Sam (backend dev, infrastructure experience)
# - Riley (domain expert, 10 years in fraud prevention)
# - Morgan (product manager)
#
# Assign roles (Data Scientist, ML Engineer, Data Engineer, MLOps Engineer, Domain Expert, PM) to each person. Justify your choices and identify any gaps.

# %% [markdown]
# ## Exercise 12: Challenge - Build a Mini MLOps Dashboard (Coding)
#
# Create a text-based "dashboard" that displays:
# - Current model version and deployment date
# - Recent accuracy trend (last 7 days)
# - Drift status for top 3 features
# - Alert status (green/yellow/red)
# - Time since last retrain
#
# Use simulated data and create a function that updates the dashboard state based on new observations.

# %%
from datetime import datetime, timedelta
from dataclasses import dataclass
from typing import List

# Your code here
