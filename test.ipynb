# %%
name = input("What is your name? ")
print("Hello", name)
# Out:
# Hello Fahim

# %%
city = input("What is your city? ")
print("Your city is", city)
print(f"{city.upper()} is a beautiful city!")
# Out:
# Your city is Bogura
# BOGURA is a beautiful city!

# %%
city = "Dhaka"

print(f"{city.upper()} is a beautiful city!")

nickname = city.lower()
print("local_spelling : ", nickname)
# Out:
# DHAKA is a beautiful city!
# local_spelling :  dhaka

# %%
age = input("What is your age? ")

print("Your age is", int(age) + 1)
# Out:
# Your age is 26

# %%
age = int(input("What is your age? "))
height = float(input("What is your height? "))

print("Your age is", age + 1)
print("Your height is", height + 1)
# Out:
# Your age is 27
# Your height is 6.4

# %%
raw = input("Enter your age: ")

while not raw.isdigit():
    print("Please type digits only!")
    raw = input("Enter your age: ")

age = int(raw)

print("Your age is", age)
# Out:
# Please type digits only!
# Your age is 14

# %%
print("5".isdigit())
print("abc".isdigit())
print("".isdigit())
print("-3".isdigit())
# Out:
# True
# False
# False
# False

# %%
name, age, address = input("Enter your name, age and address: ").split(" ")
print("Your name is", name)
print("Your age is", age)
print("Your address is", address)
# Out:
# Your name is Fahim
# Your age is 25
# Your address is Bogura
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 name, age, address = input("Enter your name, age and address: ").split(" ")
#       2 print("Your name is", name)
#       3 print("Your age is", age)
#       4 print("Your address is", address)
#
# File h:\Anaconda\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# ...

# %%
name, age, address = input("Enter your name, age and address: ").split(" ")

print("Your name is", name.upper())
print("Your age is", age)
print("Your address is", address.upper())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 name, age, address = input("Enter your name, age and address: ").split(" ")
#       2
#       3 print("Your name is", name.upper())
#       4 print("Your age is", age)
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
part = name, age, address

part = input("Enter your name, age and address: ").split(" ")
print(part)
# Out:
# ['fahim', '25', 'bogura']

# %%
name, age, address = input("Enter your name, age and address: ").split(" ")

print(f"Your name is {name}, age ({age}) and address {address}")
# Out:
# Your name is shova, age (20) and address bogura

# %%
name = input("Enter your name: ")
limit = 1000
ammount = int(input("Enter the ammount: "))

print(f"{name}, withdrawing {ammount} BDT max withdraw {limit}: ")

print("within limit:", ammount <= limit)
# Out:
# fahim, withdrawing 876 BDT max withdraw 1000:
# within limit True

# %%
principal = float(input("Enter the principal amount: "))
rate = float(input("Enter the rate: "))
years = int(input("Enter the years: "))

interest = principal * rate * years / 100
print(f"principal: {principal:.2f} BDT")
print(f"Rate : {rate}% per year, for {years} year(s)")
print(f"Interest: {interest:.2f} BDT")
total = principal + interest
print(f"Total: {total:.2f} BDT")
# Out:
# principal: 50000.00BDT
# Rate : 7.5% per year, for 5 year(s)
# Interest: 18750.00BDT
# Total: 68750.00BDT

# %%
weight = float(input("Enter your weight (kg): "))
height = float(input("Enter your height (m): "))

index = weight / height**2
print(f"Your BMI is {index:.2f}")

is_healthy = index < 25
print(f"BMI {index} considered Healthy ? : {is_healthy}")
# Out:
# Your BMI is 23.46
# BMI 23.461960986421975 considered Healthy ? : True

# %%
num = " 142 "

num2 = num.strip()  # remove spaces with .strip()
print(num2)
print(num2.isdigit())  # check if it is a digit
# Out:
# -142
# False

# %%
num = " -142 "

num2 = num.strip()  # remove spaces with .strip()
print(num2)
print(num2.isdigit())  # check if it is a digit
print(num2.startswith("-"))  #
# Out:
# -142
# False
# True

# %%
temp = 35

if temp >= 30:
    print("It is hot")
    print("Drink water")

print("This line always runs, rain or shine.")
# Out:
# It is hot
# Drink water
# This line always runs, rain or shine.

# %%
score = 900

if score >= 900:
    print("You level up!")
if score < 800:
    print("Practice more")

print("Game over. Final score:", score)
# Out:
# You level up!
# Game over. Final score: 900

# %%
mark = 30

if mark >= 60:
    print("Pass")
else:
    print("Fail")

print(f"You got {mark}/100 ")
# Out:
# Fail
# You got 30/100

# %%
mark = int(input("Enter your mark: "))

if mark >= 80:
    print("A+")
elif mark >= 70:
    print("A")
elif mark >= 60:
    print("B")
elif mark >= 50:
    print("C")
elif mark >= 33:
    print("Fail")
else:
    print("Fail")

print(f"You got {mark}/100 ")
# Out:
# A+
# You got 94/100

# %%
mark = int(input("Enter your mark: "))

if mark >= 80:
    grade = "A+"
elif mark >= 70:
    grade = "A"
elif mark >= 60:
    grade = "B"
elif mark >= 50:
    grade = "C"
else:
    grade = "F"

print(f"Mark: {mark} -> Grade: {grade}")
# Out:
# Mark: 60 -> Grade: B

# %%
age = 65

if age >= 60:
    print("Senior")
elif age >= 18:
    print("Adult")
else:
    print("Child")
# Out:
# Senior

# %%
age = 67

if age >= 18:
    print("CHARGES AS ADULT")
if age >= 60:
    print("GETS SENIOR DISCOUNT")


if age >= 60:
    category = "senior"
elif age >= 18:
    category = "adult"
else:
    category = "child"

print(f"You are a {category}")
# Out:
# CHARGES AS ADULT
# GETS SENIOR DISCOUNT
# You are a senior

# %%
has_ticket = input(f"Do you have a ticket? (y/n)")

if has_ticket == "y":
    age = int(input(f"How old are you?"))
    if age >= 18:
        print("You can enter. Enjoy the show!")
    else:
        print("You can't enter, It's too dangerous")
else:
    print("You don't have a ticket, Buy one first")
# Out:
# You can enter

# %%
subscription = "Free"

if subscription == "pro":
    pass
else:
    print("Upgrade to pro")

print(subscription)
# Out:
# Upgrade to pro
# Free

# %%
x = 5

# WRONG - this prints for EVERY value of x:
if x == 1 or 2:
    print("bug: entered the branch anyway")
# Out:
# bug: entered the branch anyway

# %%
# RIGHT - repeat the full comparison on each side:
if x == 1 or x == 2:
    print("x really is 1 or 2")
else:
    print("correct: x is neither 1 nor 2")
# Out:
# correct: x is neither 1 nor 2

# %%
def is_func(code):
    match code:
        case 1:
            return "x is 1"
        case 2:
            return "x is 2"
        case _:
            return "x is neither 1 nor 2"


print(is_func(1))
# Out:
# x is 1

# %%
code = 2

match code:
    case 1:
        print("x is 1")
    case 2:
        print("x is 2")
    case _:
        print("x is neither 1 nor 2")
# Out:
# x is 2

# %%
month = 5
day = 4

match month:
    case 1 | 2 | 3 | 4 | 5 if month == 4:
        print("spring")
    case 1 | 2 | 3 | 4 | 5 if day == 5:
        print("summer")

# %%
def status_message(code):
    match code:
        case 200:
            return "OK"
        case 301:
            return "Moved Permanently"
        case 404:
            return "Not Found"
        case 500:
            return "Internal Server Error"
        case _:
            return f"Unknown status code: {code}"


for code in [301, 404, 765]:
    print(code, "->", status_message(code))
# Out:
# 301 -> Moved Permanently
# 404 -> Not Found
# 765 -> Unknown status code: 765

# %%
def describe(x):
    match x:
        case 0:
            return "zero"
        case 1 | -1:
            return "plus or minus one"
        case other:  # captures anything left over
            return f"something else: {other!r}"


for sample in (0, -1, "banana", 3.14):
    print(describe(sample))
# Out:
# zero
# plus or minus one
# something else: 'banana'
# something else: 3.14

# %%
score = [31, 64, 12, 86, 45, 34, 98]
score.sort(reverse=True)

match score:
    case []:
        print("No score")
    case [top]:
        print(f"Top score: {top}")
    case [second]:
        print(f"Second place: {second}")
    case [third]:
        print(f"Third place: {third}")
    case [top, second, third, *others]:
        print(
            f"Top 3 -> First :{top}, Second :{second}, Third :{third}, and {len(others)} others"
        )
# Out:
# Top 3 -> First :98, Second :86, Third :64, and 4 others
